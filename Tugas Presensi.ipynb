# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafli-Putra/Pemrograman_Python/blob/main/Tugas%20Presensi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Untitled folder

# %%
ls
# Out:
# 3scene@

# %%
from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from PIL import Image
from imutils import paths
import numpy as np
import os
import cv2

# %%
print("[INFO] Loading Images ...")
image_paths = paths.list_images('3scene')
data = []
labels = []

for image_path in image_paths :
  image = Image.open(image_path)
  image = np.array(image.resize((64,64))) / 255.0
  data.append(image)
  
  label = image_path.split(os.path.sep)[-2]
  labels.append(label)

# %%
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
(trainX, testX, trainY, testY) = train_test_split(np.array(data), np.array(labels), test_size=0.25, shuffle=True)

# %%
model = Sequential(
    [
     Flatten(input_shape=(64*64*3,)),
     Dense(144, activation="relu", name="layer1"),
     Dense(24, activation="relu", name="layer2"),
     Dense(24, activation="relu", name="layer3"),
     Dense(24, activation="relu", name="layer4"),
     Dense(3, activation="softmax", name="layer5"),
    ]
)

# %%
# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, resize it to 64x64 pixels, scale
	# the pixel intensities to the range [0, 1], and then update our
	# images list
	image = Image.open(imagePath)
	image = np.array(image.resize((224, 224))) / 255.0
	data.append(image)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# %%
print("[INFO] training network ...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=65, batch_size=32)
# Out:
# [INFO] training network ...
# Epoch 1/65
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_15_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_15_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 19/23 [=======================>......] - ETA: 0s - loss: 1.6933 - accuracy: 0.3602WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_15_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - 0s 21ms/step - loss: 1.5929 - accuracy: 0.3755 - val_loss: 0.9857 - val_accuracy: 0.4219
# Epoch 2/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.9656 - accuracy: 0.5513 - val_loss: 0.8980 - val_accuracy: 0.6287
# Epoch 3/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8392 - accuracy: 0.6245 - val_loss: 0.8215 - val_accuracy: 0.6456
# Epoch 4/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8366 - accuracy: 0.6132 - val_loss: 0.8016 - val_accuracy: 0.6582
# Epoch 5/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7585 - accuracy: 0.6906 - val_loss: 0.8529 - val_accuracy: 0.5907
# Epoch 6/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7824 - accuracy: 0.6737 - val_loss: 0.7783 - val_accuracy: 0.6962
# Epoch 7/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.6921 - accuracy: 0.7328 - val_loss: 0.7965 - val_accuracy: 0.7046
# Epoch 8/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7051 - accuracy: 0.7117 - val_loss: 0.7448 - val_accuracy: 0.6709
# Epoch 9/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7698 - accuracy: 0.6723 - val_loss: 0.8515 - val_accuracy: 0.6076
# Epoch 10/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6951 - accuracy: 0.6934 - val_loss: 0.7053 - val_accuracy: 0.6920
# Epoch 11/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6406 - accuracy: 0.7201 - val_loss: 0.7211 - val_accuracy: 0.6920
# Epoch 12/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.6421 - accuracy: 0.7370 - val_loss: 0.7482 - val_accuracy: 0.6878
# Epoch 13/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5638 - accuracy: 0.7876 - val_loss: 0.8665 - val_accuracy: 0.6793
# Epoch 14/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5859 - accuracy: 0.7693 - val_loss: 0.7040 - val_accuracy: 0.7300
# Epoch 15/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5536 - accuracy: 0.7778 - val_loss: 0.6834 - val_accuracy: 0.6835
# Epoch 16/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5187 - accuracy: 0.8115 - val_loss: 0.6925 - val_accuracy: 0.7004
# Epoch 17/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5344 - accuracy: 0.7862 - val_loss: 0.7325 - val_accuracy: 0.7089
# Epoch 18/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.6245 - accuracy: 0.7496 - val_loss: 0.9055 - val_accuracy: 0.6160
# Epoch 19/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5638 - accuracy: 0.7651 - val_loss: 0.6811 - val_accuracy: 0.7131
# Epoch 20/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.5341 - accuracy: 0.7665 - val_loss: 0.7306 - val_accuracy: 0.6878
# Epoch 21/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4838 - accuracy: 0.8256 - val_loss: 0.6041 - val_accuracy: 0.7342
# Epoch 22/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4269 - accuracy: 0.8467 - val_loss: 0.5907 - val_accuracy: 0.7679
# Epoch 23/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4291 - accuracy: 0.8284 - val_loss: 0.5918 - val_accuracy: 0.7637
# Epoch 24/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4011 - accuracy: 0.8551 - val_loss: 0.7467 - val_accuracy: 0.6751
# Epoch 25/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4338 - accuracy: 0.8509 - val_loss: 0.6603 - val_accuracy: 0.7131
# Epoch 26/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3884 - accuracy: 0.8537 - val_loss: 0.5870 - val_accuracy: 0.7679
# Epoch 27/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3715 - accuracy: 0.8720 - val_loss: 0.5700 - val_accuracy: 0.7637
# Epoch 28/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3409 - accuracy: 0.8875 - val_loss: 0.6657 - val_accuracy: 0.7511
# Epoch 29/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3883 - accuracy: 0.8467 - val_loss: 0.6008 - val_accuracy: 0.7890
# Epoch 30/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3199 - accuracy: 0.8903 - val_loss: 0.5975 - val_accuracy: 0.7764
# Epoch 31/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2839 - accuracy: 0.9086 - val_loss: 0.7038 - val_accuracy: 0.7722
# Epoch 32/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3693 - accuracy: 0.8523 - val_loss: 0.7503 - val_accuracy: 0.6962
# Epoch 33/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4482 - accuracy: 0.8059 - val_loss: 0.7729 - val_accuracy: 0.7468
# Epoch 34/65
# 23/23 [==============================] - 0s 15ms/step - loss: 0.5025 - accuracy: 0.8284 - val_loss: 0.6356 - val_accuracy: 0.7722
# Epoch 35/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2751 - accuracy: 0.9015 - val_loss: 0.6294 - val_accuracy: 0.7848
# Epoch 36/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3049 - accuracy: 0.8861 - val_loss: 0.9077 - val_accuracy: 0.6751
# Epoch 37/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4033 - accuracy: 0.8481 - val_loss: 0.5430 - val_accuracy: 0.8186
# Epoch 38/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2566 - accuracy: 0.9156 - val_loss: 0.5855 - val_accuracy: 0.7722
# Epoch 39/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2643 - accuracy: 0.9170 - val_loss: 0.7553 - val_accuracy: 0.7553
# Epoch 40/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3906 - accuracy: 0.8383 - val_loss: 0.6318 - val_accuracy: 0.8059
# Epoch 41/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2418 - accuracy: 0.9255 - val_loss: 0.5462 - val_accuracy: 0.7806
# Epoch 42/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2068 - accuracy: 0.9297 - val_loss: 0.6765 - val_accuracy: 0.7426
# Epoch 43/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4831 - accuracy: 0.8045 - val_loss: 0.5854 - val_accuracy: 0.7679
# Epoch 44/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2665 - accuracy: 0.9086 - val_loss: 0.5914 - val_accuracy: 0.7890
# Epoch 45/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2007 - accuracy: 0.9466 - val_loss: 0.5741 - val_accuracy: 0.8186
# Epoch 46/65
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1678 - accuracy: 0.9536 - val_loss: 0.6756 - val_accuracy: 0.7468
# Epoch 47/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1589 - accuracy: 0.9494 - val_loss: 0.6707 - val_accuracy: 0.7975
# Epoch 48/65
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1442 - accuracy: 0.9620 - val_loss: 0.7002 - val_accuracy: 0.7637
# Epoch 49/65
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1830 - accuracy: 0.9339 - val_loss: 0.6294 - val_accuracy: 0.7932
# Epoch 50/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1871 - accuracy: 0.9339 - val_loss: 0.8519 - val_accuracy: 0.7173
# Epoch 51/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2211 - accuracy: 0.9226 - val_loss: 0.7163 - val_accuracy: 0.7890
# Epoch 52/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1890 - accuracy: 0.9409 - val_loss: 0.7807 - val_accuracy: 0.7595
# Epoch 53/65
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1770 - accuracy: 0.9339 - val_loss: 0.7612 - val_accuracy: 0.7553
# Epoch 54/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1424 - accuracy: 0.9620 - val_loss: 0.9122 - val_accuracy: 0.7342
# Epoch 55/65
# 23/23 [==============================] - 0s 15ms/step - loss: 0.2173 - accuracy: 0.9142 - val_loss: 1.0207 - val_accuracy: 0.7131
# Epoch 56/65
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1633 - accuracy: 0.9536 - val_loss: 0.7551 - val_accuracy: 0.7426
# Epoch 57/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2147 - accuracy: 0.9114 - val_loss: 0.8375 - val_accuracy: 0.7173
# Epoch 58/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.4502 - accuracy: 0.8298 - val_loss: 0.6594 - val_accuracy: 0.7595
# Epoch 59/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3451 - accuracy: 0.8861 - val_loss: 1.2014 - val_accuracy: 0.6582
# Epoch 60/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.3136 - accuracy: 0.8861 - val_loss: 0.8622 - val_accuracy: 0.7595
# Epoch 61/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1620 - accuracy: 0.9480 - val_loss: 0.8002 - val_accuracy: 0.8228
# Epoch 62/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1275 - accuracy: 0.9564 - val_loss: 0.7160 - val_accuracy: 0.7679
# Epoch 63/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1431 - accuracy: 0.9550 - val_loss: 0.8235 - val_accuracy: 0.7806
# Epoch 64/65
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1214 - accuracy: 0.9578 - val_loss: 0.7455 - val_accuracy: 0.8228
# Epoch 65/65
# 23/23 [==============================] - 0s 15ms/step - loss: 0.1067 - accuracy: 0.9761 - val_loss: 0.7272 - val_accuracy: 0.8017

# %%
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print("[INFO] evaluating network ...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network ...
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_15_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.72      0.89      0.80        82
#       forest       0.90      0.73      0.81        82
#      highway       0.83      0.78      0.80        73
#
#     accuracy                           0.80       237
#    macro avg       0.81      0.80      0.80       237
# weighted avg       0.81      0.80      0.80       237

# %%
model.save('nnmodel_scene')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: nnmodel_scene/assets

# %%
import cv2
import matplotlib.pyplot as plt
image1='coast_test.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()
# print(type(img_array))

# %%
image_testing = Image.open('coast_test.jpg')
image_testing = np.array(image_testing.resize((64, 64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 64, 64, 3)

# %%
output = model.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# [[0.9859389  0.00363478 0.01042624]]
# ['coast']
